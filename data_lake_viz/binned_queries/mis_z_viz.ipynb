# %% [markdown]
# # Import Packages and Define Functions

# %%
source("../data_lake_viz_functions.R")
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %% [markdown]
# # Import Data

# %%
mis_z_0.01 <- read.table("../../2018/apr/mis_z/2018-04-09_exac_mis_z_Default_0-10.01_binwidth_0.01_all.tsv", header=TRUE, sep="\t", quote = "", comment.char = "")
mis_z_0.01 = calculate_if_discovery(mis_z_0.01, "omim_gene_2016", "omim_gene_2018", "discovery_2016to2018")
mis_z_0.05 <- read.table("../../2018/apr/mis_z/2018-04-09_exac_mis_z_Default_0-10.01_binwidth_0.05_all.tsv", header=TRUE, sep="\t", quote = "", comment.char = "")
mis_z_0.05 = calculate_if_discovery(mis_z_0.05, "omim_gene_2016", "omim_gene_2018", "discovery_2016to2018")
mis_z_0.1 <- read.table("../../2018/apr/mis_z/2018-04-09_exac_mis_z_Default_0-10.01_binwidth_0.1_all.tsv", header=TRUE, sep="\t", quote = "", comment.char = "")
mis_z_0.1 = calculate_if_discovery(mis_z_0.1, "omim_gene_2016", "omim_gene_2018", "discovery_2016to2018")
mis_z_0.25 <- read.table("../../2018/apr/mis_z/2018-04-09_exac_mis_z_Default_0-10.01_binwidth_0.25_all.tsv", header=TRUE, sep="\t", quote = "", comment.char = "")
mis_z_0.25 = calculate_if_discovery(mis_z_0.25, "omim_gene_2016", "omim_gene_2018", "discovery_2016to2018")
mis_z_0.33 <- read.table("../../2018/apr/mis_z/2018-04-09_exac_mis_z_Default_0-10.01_binwidth_0.3333_all.tsv", header=TRUE, sep="\t", quote = "", comment.char = "")
mis_z_0.33 = calculate_if_discovery(mis_z_0.33, "omim_gene_2016", "omim_gene_2018", "discovery_2016to2018")
mis_z_0.5 <- read.table("../../2018/apr/mis_z/2018-04-06_exac_mis_z_Default_0-10.01_binwidth_0.5_all.tsv", header=TRUE, sep="\t", quote = "", comment.char = "")
mis_z_0.5 = calculate_if_discovery(mis_z_0.5, "omim_gene_2016", "omim_gene_2018", "discovery_2016to2018")

# %%
visualize(mis_z_0.5, 2016, "Missense Z-score, OMIM 2016", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_bar).”
# plot without title

# %%
visualize(mis_z_0.5, 2018, "Missense Z-score, OMIM 2018", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_bar).”
# plot without title

# %%
visualize(mis_z_0.33, 2016, "Missense Z-score, OMIM 2016", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_bar).”
# plot without title

# %%
visualize(mis_z_0.33, 2018, "Missense Z-score, OMIM 2018", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_bar).”
# plot without title

# %%
visualize(mis_z_0.25, 2016, "Missense Z-score, OMIM 2016", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_bar).”
# plot without title

# %%
visualize(mis_z_0.25, 2018, "Missense Z-score, OMIM 2018", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_bar).”
# plot without title

# %%
visualize(mis_z_0.1, 2016, "Missense Z-score, OMIM 2016", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# plot without title

# %%
visualize(mis_z_0.1, 2018, "Missense Z-score, OMIM 2018", "mis_z", x_limits=c(-0.05,10), x_breaks=seq(0,10,1), only16_18=TRUE)
# Out:
# plot without title
